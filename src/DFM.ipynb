# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches


# Model agnostic 
from typing import Optional, List, Callable, Dict, Any, List
from pathlib import Path
from utils import Helm, QLatticeWrapper
from dfm_src import DFT
# Out:
# This version of Feyn and the QLattice is available for academic, personal, and non-commercial use. By using the community version of this software you agree to the terms and conditions which can be found at https://abzu.ai/eula.

# %%
# Get the directory this file lives in
nb_dir = Path.cwd() # notebook directory
project_root = nb_dir.parents[0] # project directory
data_path = project_root / "datasets" / "processed_well_data.csv"

includ_cols = ['Dia', 'Dev(deg)','Area (m2)', 'z','GasDens','LiquidDens', 'g (m/s2)', 'P/T','friction_factor', 'critical_film_thickness']
D = Helm(path=data_path, includ_cols=includ_cols, test_size=0.20, scale=False) # cannot scale input units

# %%
# define xgboost pipeline
def dft(
        hparams: Dict[str, Any]
):
    dft = DFT(
        **hparams,
    )

    return dft

hparam_grid = {
            "dev_tol":   [1e-5, 1e-4, 1e-2],
            "feature_tol": [0.5, 1.0, 2.0],
            "interval": [0.05, 0.10],  # Classification tolerance for well status
        }

# train model and optimize hyperparameters via grid search 
trained_model = D.evolv_model(build_model=dft, hparam_grid=hparam_grid, k_folds=5)
# Out:
# Training model and optimizing hyperparameters via k-fold CV...
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# /Users/deanmsweeney/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 18
#      11 hparam_grid = {
#      12             "dev_tol":   [1e-5, 1e-4, 1e-2],
#      13             "feature_tol": [0.5, 1.0, 2.0],
#      14             "interval": [0.05, 0.10],  # Classification tolerance for well status
#      15         }
#      17 # train model and optimize hyperparameters via grid search
# ---> 18 trained_model = D.evolv_model(build_model=dft, hparam_grid=hparam_grid, k_folds=5)
#
# File ~/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/utils.py:300, in Helm.evolv_model(self, build_model, hparam_grid, k_folds)
#     295 model_hparams = {
#     296     k: v for k, v in search_hparams.items() if k != "interval"
#     297 }
#     299 model = build_model(hparams=model_hparams)
# --> 300 score, score_std = self._cross_val(model, interval=interval)
#     302 if score > self.best_score:
#     303     self.best_score = score
#
# File ~/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/utils.py:245, in Helm._cross_val(self, model, interval)
#     243     model.fit(X_tr, x_dot=y_tr_rdy)
#     244 else:
# --> 245     model.fit(X_tr, y_tr_rdy)
#     247 y_val_pred = model.predict(X_val)
#     248 if self.scale:
#
# File ~/Documents/UM-Google Drive/Classes/ChE 696/project/symbolic-machine-learning-liquidloading/src/dfm_src.py:96, in DFT.fit(self, X, y)
#      94 x0 = np.concatenate(([1.0, 1.0, 0.5, 1.0, 1.0], np.full(n_train, 0.5)))
#      95 bounds = [(None, None)] * 5 + [(0.0, 1.0)] * n_train
# ---> 96 result = minimize(self._loss, x0=x0, bounds=bounds, method="Powell",
#      97               options={'maxiter': 5000, 'maxfun': 10000, 'disp': False}) #(f, x0)
#      99 if result.success:
#     100     self.opt_params = result.x
#
# File /opt/anaconda3/envs/droplet_film/lib/python3.10/site-packages/scipy/optimize/_minimize.py:701, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     698     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     699                                **options)
#     700 elif meth == 'powell':
# --> 701     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#     702 elif meth == 'cg':
#     703     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#
# File /opt/anaconda3/envs/droplet_film/lib/python3.10/site-packages/scipy/optimize/_optimize.py:3507, in _minimize_powell(func, x0, args, callback, bounds, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    3505 direc1 = direc[i]
#    3506 fx2 = fval
# -> 3507 fval, x, direc1 = _linesearch_powell(func, x, direc1,
#    3508                                      tol=xtol * 100,
#    3509                                      lower_bound=lower_bound,
#    3510                                      upper_bound=upper_bound,
#    3511                                      fval=fval)
#    3512 if (fx2 - fval) > delta:
#    3513     delta = fx2 - fval
#
# File /opt/anaconda3/envs/droplet_film/lib/python3.10/site-packages/scipy/optimize/_optimize.py:3195, in _linesearch_powell(func, p, xi, tol, lower_bound, upper_bound, fval)
#    3192     return _linesearch_powell(func, p, xi, fval=fval, tol=tol)
#    3193 elif not np.isneginf(bound[0]) and not np.isposinf(bound[1]):
#    3194     # we can use a bounded scalar minimization
# -> 3195     res = _minimize_scalar_bounded(myfunc, bound, xatol=tol / 100)
#    3196     xi = res.x * xi
#    3197     return squeeze(res.fun), p + xi, xi
#
# File /opt/anaconda3/envs/droplet_film/lib/python3.10/site-packages/scipy/optimize/_optimize.py:2311, in _minimize_scalar_bounded(func, bounds, args, xatol, maxiter, disp, **unknown_options)
#    2309 if q > 0.0:
#    2310     p = -p
# -> 2311 q = np.abs(q)
#    2312 r = e
#    2313 e = rat
#
# KeyboardInterrupt:
