# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import pandas as pd
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score
from sklearn.model_selection import train_test_split
from pysindy import SINDy
from sklearn.preprocessing import StandardScaler
from pysindy.optimizers import STLSQ
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import StratifiedKFold 
from pysindy.feature_library import PolynomialLibrary, FourierLibrary, GeneralizedLibrary

# %%
df = pd.read_csv("processed_well_data.csv")

# %%
print(df.isnull().sum())
# Out:
# Well no                    0
# Dia                        0
# Dev(deg)                   0
# LiquidFlowrate             0
# Gasflowrate                0
# Area (m2)                  0
# z                          0
# GasDens                    0
# Condesnate Presence        0
# Water presence             0
# LiquidDens                 0
# GasVis                     0
# LiqVis                     0
# g (m/s2)                   0
# Test Vg                    0
# P/T                        0
# Test status                0
# Vsg                        0
# Vsl                        0
# Rel                        0
# Reg                        0
# film thickness             0
# d(0,90)                    0
# d(15,90)                   0
# d(30,90)                   0
# d(45,90)                   0
# d(60,90)                   0
# d(90,90)                   0
# d(120,90)                  0
# d(150,90)                  0
# d(180,90)                  0
# d(210,90)                  0
# d(270,90)                  0
# d(360,90)                  0
# friction_factor            0
# critical_film_thickness    0
# Qcr                        0
# ΔQ                         0
# dtype: int64

# %% [markdown]
# # Data preparation

# %%
# split features
#X = df[['Dia', 'Dev(deg)','Area (m2)', 'z','GasDens','LiquidDens', 'P/T','friction_factor', 'critical_film_thickness']]
X = df.drop(columns=['Qcr', 'Test status', 'ΔQ', 'Well no'])
print(X.shape)

y = df['Qcr']
gsflow = df['Gasflowrate']  # additional target for classification metrics

# load class labels: loaded/unloaded/near loaded
loading_class = df['Test status'].apply(
    lambda x: -1 if x == 'Unloaded' else (0 if x == 'Near L.U' else 1)).to_numpy()

#pPerform the train-test split, making sure to split all targets simultaneously
X_train, X_test, y_train, y_test, gsflow_train, gsflow_test, loading_train, loading_test = train_test_split(
    X, y, gsflow, loading_class, test_size=0.20, random_state=42, stratify=loading_class
)

"""
For final evaluation of the model, we need designate test data and normalize to all training data
"""
# scale features and continuous target (Qcr)
scaler_X = StandardScaler()
scaler_y = StandardScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)
X_scaled = scaler_X.transform(X)

y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1))
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1))
y_scaled = scaler_y.transform(y.values.reshape(-1, 1))

# t_train is just an index array for plotting
t_train = np.arange(len(y_train_scaled))
t = np.arange(len(y_scaled))

#convert to a numpy array and store test data 
loading_train = np.array(loading_train)
loading_test = np.array(loading_test)
loading = np.array(loading_class)
gsflow_test = np.array(gsflow_test)
gsflow = np.array(gsflow)
y_test = np.array(y_test)
y = np.array(y)
# Out:
# (208, 34)

# %%
# accuracy metric and confusion matrix 
def calculate_accuracy(y_pred, gsflow, loading_actual, interval):
    loading_pred = np.where(y_pred > gsflow + interval, 1, 
                          np.where(y_pred < gsflow - interval, -1, 0))
    return accuracy_score(loading_actual, loading_pred), confusion_matrix(loading_actual, loading_pred,  labels=[-1, 0, 1])

# %%
# If you haven’t installed Boruta yet, uncomment the following line:
from boruta import BorutaPy
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# 1. Initialize a Random Forest regressor for Boruta
rf = RandomForestRegressor(
    n_jobs=-1,
    max_depth=5,
    random_state=42
)

# 2. Set up the Boruta feature selector
boruta_selector = BorutaPy(
    estimator=rf,
    n_estimators='auto',        # let Boruta decide how many trees to use
    verbose=2,                  # log progress
    random_state=42
)

# 3. Fit Boruta on your (scaled) training data
#    BorutaPy expects X to be numpy array and y to be 1d array
boruta_selector.fit(
    X_train_scaled, 
    y_train_scaled.ravel()
)

# 4. Retrieve the mask and names of selected features
selected_mask = boruta_selector.support_
selected_features = X.columns[selected_mask]
print("👉 Selected features by Boruta:", list(selected_features))

# 5. Transform your datasets to keep only the selected features
X_train_boruta = boruta_selector.transform(X_train_scaled)
X_test_boruta  = boruta_selector.transform(X_test_scaled)

# 6. (Optional) Retrain a Random Forest on the reduced feature set
rf_final = RandomForestRegressor(random_state=42)
rf_final.fit(X_train_boruta, y_train_scaled.ravel())

# 7. Evaluate on the test set
y_pred_scaled = rf_final.predict(X_test_boruta)
mse = mean_squared_error(y_test_scaled, y_pred_scaled)
r2  = r2_score(y_test_scaled, y_pred_scaled)
print(f"Test MSE (scaled): {mse:.4f}")
print(f"Test R² (scaled):  {r2:.4f}")

# 8. (If you want to interpret in original units) inverse-transform
y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1,1)).ravel()
print("Test MSE (original Qcr):", mean_squared_error(y_test, y_pred))

acc, cm = calculate_accuracy(y_pred, gsflow_test, loading_test, interval=0.01)
print(acc)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	34
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	34
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	34
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	34
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	34
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	34
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	34
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	3
# Tentative: 	4
# Rejected: 	27
# Iteration: 	9 / 100
# Confirmed: 	3
# Tentative: 	4
# Rejected: 	27
# Iteration: 	10 / 100
# Confirmed: 	3
# Tentative: 	4
# Rejected: 	27
# Iteration: 	11 / 100
# Confirmed: 	3
# Tentative: 	4
# Rejected: 	27
# Iteration: 	12 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	28
# Iteration: 	13 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	28
# Iteration: 	14 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	28
# Iteration: 	15 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	28
# Iteration: 	16 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	28
# Iteration: 	17 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	28
# Iteration: 	18 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	28
# Iteration: 	19 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	28
# Iteration: 	20 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	28
# Iteration: 	21 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	28
# Iteration: 	22 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	23 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	24 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	25 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	26 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	27 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	28 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	29 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	30 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	31 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	32 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	33 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	34 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	35 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	36 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	37 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	38 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	39 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	40 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	41 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	42 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	43 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	44 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	45 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	46 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	47 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	48 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	28
# Iteration: 	49 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	50 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	51 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	52 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	53 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	54 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	55 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	56 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	57 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	58 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	59 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	60 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	61 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	62 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	63 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	64 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	65 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	66 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	67 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	68 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	69 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	70 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	71 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	72 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	73 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	74 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	75 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	76 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	77 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	78 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	79 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	80 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	81 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	82 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	83 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	84 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	85 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	86 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	87 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	88 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	89 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	90 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	91 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	92 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	93 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	94 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	95 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	96 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	97 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	98 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# Iteration: 	99 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	28
# 👉 Selected features by Boruta: ['Gasflowrate', 'Area (m2)', 'z', 'GasDens', 'Test Vg']
# Test MSE (scaled): 0.4440
# Test R² (scaled):  0.5264
# Test MSE (original Qcr): 7021922647.481755
# 0.7619047619047619

# %%
# K-fold cross validation
def evaluate_sindy(params, X, y, gsflow, loading_class, cv_splits=5):
    alpha, threshold, interval, n, f = params
    
    # Use StratifiedKFold to preserve class balance in splits
    kf = StratifiedKFold(n_splits=cv_splits, shuffle=True, random_state=42)

    acc_scores = []
    
    for train_idx, val_idx in kf.split(X, loading_class):  # Using validation split from training data
        # divide into trianing/validation sets
        X_train_cv, X_val_cv = X[train_idx], X[val_idx]
        y_train_cv, y_val_cv = y[train_idx], y[val_idx]
        gsflow_val_cv = gsflow[val_idx]
        loading_val_cv = loading_class[val_idx]
        
        scaler_X = StandardScaler()
        X_train_cv_scaled = scaler_X.fit_transform(X_train_cv)
        X_val_cv_scaled = scaler_X.transform(X_val_cv)
        
        scaler_y = StandardScaler()
        y_train_cv_scaled = scaler_y.fit_transform(y_train_cv.reshape(-1, 1))
        
        # Define optimizer for SINDy
        optimizer = STLSQ(
            alpha=alpha,
            threshold=threshold,
            max_iter=10000,
            normalize_columns=True
        )
        
        # Train model
        fourier_library = FourierLibrary(n_frequencies=int(f))
        poly_library = PolynomialLibrary(degree=int(n))
        lib = GeneralizedLibrary([poly_library, fourier_library])

        model = SINDy(optimizer=optimizer, feature_library=lib)
        model.fit(X_train_cv_scaled, t=np.arange(len(y_train_cv_scaled)), 
                 x_dot=y_train_cv_scaled)
        
        # Compute performance on validation set 
        y_val_pred_scaled = model.predict(X_val_cv_scaled)
        y_val_pred_cv = scaler_y.inverse_transform(y_val_pred_scaled).flatten()
        
        acc, cm = calculate_accuracy(y_val_pred_cv, gsflow_val_cv, loading_val_cv, interval)
        acc_scores.append(acc)
    
    return np.mean(acc_scores)

# %%
def optimize_sindy_hyperparameters(X_train, y_train, gsflow_train, loading_train, param_grid):
    best_score = -1
    best_params = None
    
    X_train = np.array(X_train)
    y_train = np.array(y_train).flatten()
    gsflow_train = np.array(gsflow_train)
    loading_train = np.array(loading_train)
    
    print("Begin training and hyperparameter optimization...")
    for alpha in param_grid['alpha']:
        for threshold in param_grid['threshold']:
            for interval in param_grid['interval']:
                for n in param_grid['n']:
                    for f in param_grid['f']:
                        score = evaluate_sindy((alpha, threshold, interval, n, f), 
                                            X_train, y_train, gsflow_train, loading_train)
                    
                    if score > best_score:
                        best_score = score
                        best_params = {'alpha': alpha, 'threshold': threshold, 'interval': interval, 'n': n}
    
    return best_params, best_score

# %%
# Grid search for optimal hyperparameters 
param_grid = {
    'alpha': np.logspace(-4, 0.25, 10),      
    'threshold': np.logspace(-4, -1, 10),  
    'interval': np.linspace(0, 10, 10) , 
    'n': np.array([1, 2, 3, 5]),
    'f':np.array([1, 2, 3, 4, 5])
}

#  Train model and optimize hyperparameters 
best_params, best_score = optimize_sindy_hyperparameters(
    X_train, y_train, gsflow_train, loading_train, param_grid
)

print("\nBest parameters found:")
print(best_params)
print(f"Best CV accuracy: {best_score*100:.2f}%")

# Train final model on FULL training set with best params and evaluate on the final test set
final_optimizer = STLSQ(
    alpha=best_params['alpha'],
    threshold=best_params['threshold'],
    max_iter=10000,
    normalize_columns=True
)

# Evaluate model performance 
fourier_library = FourierLibrary(n_frequencies=int(best_params['n']))
poly_library = PolynomialLibrary(degree=int(best_params['n']))
lib = GeneralizedLibrary([poly_library, fourier_library])

final_model = SINDy(optimizer=final_optimizer, feature_library=lib)
final_model.fit(X_train_scaled, t=t_train, x_dot=y_train_scaled)

# Evaluate on trainin set
y_pred_train_scaled = final_model.predict(X_train_scaled)
y_pred_train = scaler_y.inverse_transform(y_pred_train_scaled).flatten()

# Evaluate on TEST set (previously unseen data)
y_pred_test_scaled = final_model.predict(X_test_scaled)
y_pred_test = scaler_y.inverse_transform(y_pred_test_scaled).flatten()

# Calculate metrics on TEST set
train_acc, train_cm = calculate_accuracy(y_pred_train, gsflow_train, loading_train, best_params['interval'])
test_acc, test_cm = calculate_accuracy(y_pred_test, gsflow_test, loading_test, best_params['interval'])

print("\n=== Final Model Performance ===")
final_model.print()
print(f"\nTraining Set Classification Accuracy: {train_acc*100:.2f}%")
print(f"Test Set Classification Accuracy: {test_acc*100:.2f}%")

print("Confusion Matrix for Train Set Classification")
print(train_cm)
print("Confusion Matrix for Test Set Classification")
print(test_cm)
# Out:
# Begin training and hyperparameter optimization...
#
# Best parameters found:
# {'alpha': 0.007742636826811269, 'threshold': 0.046415888336127774, 'interval': 0.0, 'n': 1}
# Best CV accuracy: 66.88%
#
# === Final Model Performance ===
# (x0)' = 4.864 1 + -1.173 x0 + 0.959 x1 + 1.727 x2 + -0.009 x3 + 0.026 x4 + -0.598 x5 + 0.239 x6 + 0.305 x7 + -0.072 x8 + 1.344 sin(1 x0) + -0.265 cos(1 x0) + -1.106 sin(1 x1) + -0.439 cos(1 x1) + -0.400 sin(1 x2) + 1.329 cos(1 x2) + 0.093 sin(1 x3) + -0.107 cos(1 x3) + 1.149 sin(1 x4) + -6.401 cos(1 x4) + 0.505 sin(1 x5) + 1.165 cos(1 x5) + 0.077 sin(1 x6) + 0.562 cos(1 x6) + -0.409 sin(1 x7) + -0.047 cos(1 x7) + 0.486 sin(1 x8)
#
# Training Set Classification Accuracy: 68.67%
# Test Set Classification Accuracy: 61.90%
# Confusion Matrix for Train Set Classification
# [[43  0 45]
#  [ 0  0  5]
#  [ 2  0 71]]
# Confusion Matrix for Test Set Classification
# [[10  0 13]
#  [ 0  0  1]
#  [ 2  0 16]]

# %% [markdown]
# # Classification graph for well status

# %%
# Set a high-quality theme for publication
sns.set_theme(style="whitegrid", context="paper", font_scale=1.5)

# Define the color mapping for the "Test status"
color_map = {
    "Loaded": "red",
    "Unloaded": "green",
    "Questionable": "orange",
    "Near L.U": "blue"
}

# Evalute entire model performance
y_pred_scaled = final_model.predict(X_scaled)
y_pred = scaler_y.inverse_transform(y_pred_scaled).flatten()

# Slice the first 40 entries for plotting.
gasflow_subset = gsflow
y_pred_subset = y_pred
colors_subset = df['Test status'].map(color_map).fillna("gray")

# Create a high-resolution figure.
plt.figure(figsize=(10, 8), dpi=300)
plt.scatter(gasflow_subset, y_pred_subset, c=colors_subset, alpha=0.7, s = 150, edgecolors="black", label="gplearn Predictions")

plt.plot([0, 350000], [0, 350000], [min(y_pred[:42]), max(y_pred[:42])], '--r')


# Set bold axis labels with increased font sizes.
plt.title("PySINDy Model", fontsize=18, fontweight='bold')
plt.xlabel("Well measured flow rate (m³/day)", fontsize=18, fontweight='bold')
plt.ylabel("Critical rate (m³/day)", fontsize=18, fontweight='bold')
plt.grid(True)
plt.xlim(0, 350000)
plt.ylim(0, 350000)

# Create legend patches from the color map.
legend_patches = [mpatches.Patch(color=color, label=status) for status, color in color_map.items()]
# legend_patches.append(mpatches.Patch(color="gray", label="Unknown"))
plt.legend(handles=legend_patches, title='Actual label', fontsize=14, title_fontsize=16)

plt.tight_layout()
plt.savefig("high_quality_scatter_gao.pdf", format="pdf", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# # Fit model for literature comparsion

# %%
# Split features
X = df[['Dia', 'Dev(deg)','Area (m2)', 'z','GasDens','LiquidDens', 'P/T','friction_factor', 'critical_film_thickness']]
y = df['Qcr']
gsflow = df['Gasflowrate']  # This is your additional target for classification metrics

# load class labels: loaded/unloaded/near loaded
loading_class = df['Test status'].apply(
    lambda x: -1 if x == 'Unloaded' else (0 if x == 'Near L.U' else 1)).to_numpy()

# Perform the train-test split, making sure to split all targets simultaneously
X_train, X_test, y_train, y_test, gsflow_train, gsflow_test, loading_train, loading_test = train_test_split(
    X, y, gsflow, loading_class, test_size=0.20, random_state=42, stratify=loading_class
)

"""
For final evaluation of the model, we need designate test data and normalize to all training data
"""
# Scale your features and continuous target (Qcr)
scaler_X = StandardScaler()
scaler_y = StandardScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)
X_scaled = scaler_X.transform(X)

y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1))
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1))
y_scaled = scaler_y.transform(y.values.reshape(-1, 1))

# t_train is just an index array for plotting
t_train = np.arange(len(y_train_scaled))
t = np.arange(len(y_scaled))

#convert to a numpy array and store test data 
loading_train = np.array(loading_train)
loading_test = np.array(loading_test)
loading = np.array(loading_class)
gsflow_test = np.array(gsflow_test)
gsflow = np.array(gsflow)
y_test = np.array(y_test)
y = np.array(y)
